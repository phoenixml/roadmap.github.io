# %%
# !apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.12 [154 kB]
# Fetched 154 kB in 1s (232 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking poppler-utils (0.62.0-2ubuntu2.12) ...
# Setting up poppler-utils (0.62.0-2ubuntu2.12) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !pip install graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from graphviz import Digraph
import graphviz

# %% [markdown]
# #Display RoadMap Code

# %%
# !cat graph.dot
# Out:
# Digraph TrackA{
# rankdir="LR"
# node [fontsize=250, width=10]
# edge [fontsize=250]
# node [colorscheme=oranges9]
# node [fontname="Helvetica,Arial,sans-serif"]
# edge [fontname="Helvetica,Arial,sans-serif"]
#
# subgraph CNN {
# 	//	node [style=];
# 	//rank = same
# 		n13
# 		//label = "process #2";
# 	//	color=
# 		#**************************** PAT ***********************
# //"n2" [label="A/ PAT" , shape=plaintext]
# "n3" [label="M-NTM/ PAT", shape=plaintext]
# //"n4" [label="A Track - Known and Unknown VM",  shape=ellipse]
#
# #"n11" -> "n9" [arrowhead=none]
# "n5" [label="A-JPEG/ PAT", shape=plaintext, width=50]
# "n6" [label="A-StAdv/ PAT", shape=plaintext]
#
# "n7" [label="A-ReCAdv/ PAT", shape=plaintext]
# "n8" [label="A-LPA/ PAT", shape=plaintext]
# "n9" [label="A-Fast-LPA/ PAT", shape=plaintext]
# //"n10"[label="A-PPGD/ PAT", shape=plaintext]
# # DNN Connections from Attack to DNN
# "n13"-> "n5027" [label="PC=JPEG"]
# "n5027" [label="Visibility=Visible",shape=plaintext]
# ...

# %% [markdown]
# You can Edit the above code directly on http://magjac.com/graphviz-visual-editor/

# %% [markdown]
# #Convert Dot to PDF

# %%
with open("graph.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph).render(view=True)
# Out:
# 'Source.gv.pdf'

# %% [markdown]
# #Display Roadmap as SVG

# %%
# !pip install svgpathtools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 67 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.6 MB/s
# ...

# %%
from IPython.display import SVG, display, HTML
from svgpathtools import wsvg, Path, Line, CubicBezier
from svgpathtools.parser import parse_transform
from svgpathtools.path import transform as path_transform
import base64

SVG(filename="/content/Source.svg")
display(SVG(filename="/content/Source.svg"))

# %% [markdown]
# #Display Roadmap PDF as Image
# Download PDF file for a full Roadmap View

# %%
from pdf2image import convert_from_path, convert_from_bytes
from IPython.display import display, Image

images = convert_from_bytes(open('/content/Source.gv.pdf', 'rb').read(), size=800)
display(images[0])
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=800x629 at 0x7FA47F83FA10>
